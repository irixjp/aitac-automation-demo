# %%
ansible-playbook 01_tower_manager_deploy.yml
# Out:
# PLAY [localhost] ***************************************************************
#
# TASK [ec2_instance_create : create ec2 instances] ******************************
# changed: [127.0.0.1]
#
# TASK [ec2_instance_create : debug] *********************************************
# ok: [127.0.0.1] => {
#     "ec2": {
#         "changed": true,
#         "failed": false,
#         "instance_ids": [
#             "i-0c48d90eef038f275",
#             "i-0d5f40014e389f213"
#         ],
#         "instances": [
#             {
#                 "ami_launch_index": "0",
#                 "architecture": "x86_64",
#                 "block_device_mapping": {
#                     "/dev/sda1": {
#                         "delete_on_termination": true,
#                         "status": "attached",
#                         "volume_id": "vol-06a194ea953cd5c1c"
#                     }
#                 },
#                 "dns_name": "ec2-52-68-110-4.ap-northeast-1.compute.amazonaws.com",
# ...

# %%
ansible-playbook 01_tower_manager_deploy.yml
# Out:
# PLAY [localhost] ***************************************************************
#
# TASK [ec2_instance_create : create ec2 instances] ******************************
# changed: [127.0.0.1]
#
# TASK [ec2_instance_create : debug] *********************************************
# ok: [127.0.0.1] => {
#     "ec2": {
#         "changed": true,
#         "failed": false,
#         "instance_ids": [
#             "i-01e0df4ef95b4f45f"
#         ],
#         "instances": [
#             {
#                 "ami_launch_index": "0",
#                 "architecture": "x86_64",
#                 "block_device_mapping": {
#                     "/dev/sda1": {
#                         "delete_on_termination": true,
#                         "status": "attached",
#                         "volume_id": "vol-066106b2b7f0405fb"
#                     }
#                 },
#                 "dns_name": "ec2-13-230-211-48.ap-northeast-1.compute.amazonaws.com",
#                 "ebs_optimized": false,
# ...

# %%
ansible-playbook 01_tower_manager_deploy.yml
# Out:
# PLAY [localhost] ***************************************************************
#
# TASK [ec2_instance_create : create ec2 instances] ******************************
# changed: [127.0.0.1]
#
# TASK [ec2_instance_create : debug] *********************************************
# ok: [127.0.0.1] => {
#     "ec2": {
#         "changed": true,
#         "failed": false,
#         "instance_ids": [
#             "i-03a0ba7defd7e2fb4"
#         ],
#         "instances": [
#             {
#                 "ami_launch_index": "0",
#                 "architecture": "x86_64",
#                 "block_device_mapping": {
#                     "/dev/sda1": {
#                         "delete_on_termination": true,
#                         "status": "attached",
#                         "volume_id": "vol-087efd4a4c1e47bbe"
#                     }
#                 },
#                 "dns_name": "ec2-52-196-244-242.ap-northeast-1.compute.amazonaws.com",
#                 "ebs_optimized": false,
# ...

# %%
which tower-cli
# Out:
# /usr/local/bin/tower-cli

# %%
tower-cli --version
# Out:
# Tower CLI 3.2.1

# %%
ansible-playbook 99_instance_delete.yml
# Out:
# PLAY [localhost] ***************************************************************
#
# TASK [ec2_instance_delete_by_tag : gathering ec2 instance facts] ***************
# ok: [127.0.0.1]
#
# TASK [ec2_instance_delete_by_tag : debug] **************************************
# ok: [127.0.0.1] => {
#     "ec2": {
#         "changed": false,
#         "failed": false,
#         "instances": [
#             {
#                 "ami_launch_index": 0,
#                 "architecture": "x86_64",
#                 "block_device_mappings": [
#                     {
#                         "device_name": "/dev/sda1",
#                         "ebs": {
#                             "attach_time": "2018-01-17T06:08:04+00:00",
#                             "delete_on_termination": false,
#                             "status": "attached",
#                             "volume_id": "vol-0ff9746871fd25c89"
#                         }
#                     }
#                 ],
# ...

# %%
ansible-playbook 99_instance_delete.yml
# Out:
# PLAY [localhost] ***************************************************************
#
# TASK [ec2_instance_delete_by_tag : gathering ec2 instance facts] ***************
# ok: [127.0.0.1]
#
# TASK [ec2_instance_delete_by_tag : debug] **************************************
# ok: [127.0.0.1] => {
#     "ec2": {
#         "changed": false,
#         "failed": false,
#         "instances": [
#             {
#                 "ami_launch_index": 0,
#                 "architecture": "x86_64",
#                 "block_device_mappings": [
#                     {
#                         "device_name": "/dev/sda1",
#                         "ebs": {
#                             "attach_time": "2018-01-17T06:08:04+00:00",
#                             "delete_on_termination": false,
#                             "status": "attached",
#                             "volume_id": "vol-0ff9746871fd25c89"
#                         }
#                     }
#                 ],
# ...

# %%
ansible-playbook 99_instance_delete.yml
# Out:
# PLAY [localhost] ***************************************************************
#
# TASK [ec2_instance_delete_by_tag : gathering ec2 instance facts] ***************
# ok: [127.0.0.1]
#
# TASK [ec2_instance_delete_by_tag : debug] **************************************
# ok: [127.0.0.1] => {
#     "ec2": {
#         "changed": false,
#         "failed": false,
#         "instances": [
#             {
#                 "ami_launch_index": 0,
#                 "architecture": "x86_64",
#                 "block_device_mappings": [
#                     {
#                         "device_name": "/dev/sda1",
#                         "ebs": {
#                             "attach_time": "2018-01-17T06:08:04+00:00",
#                             "delete_on_termination": false,
#                             "status": "attached",
#                             "volume_id": "vol-0ff9746871fd25c89"
#                         }
#                     }
#                 ],
# ...

# %%
ansible-playbook 99_instance_delete.yml
# Out:
# PLAY [localhost] ***************************************************************
#
# TASK [ec2_instance_delete_by_tag : gathering ec2 instance facts] ***************
# ok: [127.0.0.1]
#
# TASK [ec2_instance_delete_by_tag : debug] **************************************
# ok: [127.0.0.1] => {
#     "ec2": {
#         "changed": false,
#         "failed": false,
#         "instances": [
#             {
#                 "ami_launch_index": 0,
#                 "architecture": "x86_64",
#                 "block_device_mappings": [
#                     {
#                         "device_name": "/dev/sda1",
#                         "ebs": {
#                             "attach_time": "2018-01-17T06:08:04+00:00",
#                             "delete_on_termination": false,
#                             "status": "attached",
#                             "volume_id": "vol-0ff9746871fd25c89"
#                         }
#                     }
#                 ],
# ...

# %%
ansible-playbook 99_instance_delete.yml
# Out:
# PLAY [localhost] ***************************************************************
#
# TASK [ec2_instance_delete_by_tag : gathering ec2 instance facts] ***************
# ok: [127.0.0.1]
#
# TASK [ec2_instance_delete_by_tag : debug] **************************************
# ok: [127.0.0.1] => {
#     "ec2": {
#         "changed": false,
#         "failed": false,
#         "instances": [
#             {
#                 "ami_launch_index": 0,
#                 "architecture": "x86_64",
#                 "block_device_mappings": [
#                     {
#                         "device_name": "/dev/sda1",
#                         "ebs": {
#                             "attach_time": "2018-01-17T06:08:04+00:00",
#                             "delete_on_termination": false,
#                             "status": "attached",
#                             "volume_id": "vol-0ff9746871fd25c89"
#                         }
#                     }
#                 ],
# ...

# %%
ansible-playbook 01_tower_manager_deploy.yml
# Out:
# PLAY [localhost] ***************************************************************
#
# TASK [ec2_instance_create : create ec2 instances] ******************************
# changed: [127.0.0.1]
#
# TASK [ec2_instance_create : debug] *********************************************
# ok: [127.0.0.1] => {
#     "ec2": {
#         "changed": true,
#         "failed": false,
#         "instance_ids": [
#             "i-0639a83a4cbf33770"
#         ],
#         "instances": [
#             {
#                 "ami_launch_index": "0",
#                 "architecture": "x86_64",
#                 "block_device_mapping": {
#                     "/dev/sda1": {
#                         "delete_on_termination": true,
#                         "status": "attached",
#                         "volume_id": "vol-01a301a1312e27c78"
#                     }
#                 },
#                 "dns_name": "ec2-13-113-246-84.ap-northeast-1.compute.amazonaws.com",
#                 "ebs_optimized": false,
# ...

# %%
ansible-playbook 99_instance_delete.yml
# Out:
# PLAY [localhost] ***************************************************************
#
# TASK [ec2_instance_delete_by_tag : gathering ec2 instance facts] ***************
# ok: [127.0.0.1]
#
# TASK [ec2_instance_delete_by_tag : debug] **************************************
# ok: [127.0.0.1] => {
#     "ec2": {
#         "changed": false,
#         "failed": false,
#         "instances": [
#             {
#                 "ami_launch_index": 0,
#                 "architecture": "x86_64",
#                 "block_device_mappings": [
#                     {
#                         "device_name": "/dev/sda1",
#                         "ebs": {
#                             "attach_time": "2018-01-17T11:59:28+00:00",
#                             "delete_on_termination": true,
#                             "status": "attached",
#                             "volume_id": "vol-01a301a1312e27c78"
#                         }
#                     }
#                 ],
# ...
